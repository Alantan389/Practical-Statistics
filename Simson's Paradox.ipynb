# %% [markdown]
# # Simpson's Paradox

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
Image(filename='/Users/balance/Desktop/1.png')

# %%
Image(filename='/Users/balance/Desktop/2.png')

# %%
import pandas as pd

# %%
admits=pd.read_csv('/Users/balance/Desktop/udacity-review/Practical Statistics/admission_data.csv')
admits.head()
# Out:
#    student_id  gender      major  admitted
# 0       35377  female  Chemistry     False
# 1       56105    male    Physics      True
# 2       31441  female  Chemistry     False
# 3       51765    male    Physics      True
# 4       53714  female    Physics      True

# %% [markdown]
# ## Proportion and admission rate for each gender

# %%
## Proportion of female
len(admits[admits['gender']=='female'])
# Out:
# 257

# %%
len(admits[admits['gender']=='male'])
# Out:
# 243

# %%
len(admits[admits['gender']=='female']) / admits.shape[0]
# Out:
# 0.514

# %%
## Proportion of male
len(admits[admits['gender']=='male']) / admits.shape[0]
# Out:
# 0.486

# %%
# Admission rate for females
len(admits[(admits['gender']=='female') & (admits['admitted'])])/(len(admits[admits['gender']=='female']))
# Out:
# 0.28793774319066145

# %%
# Admission rate for males
len(admits[(admits['gender']=='male') & (admits['admitted'])])/(len(admits[admits['gender']=='male']))
# Out:
# 0.48559670781893005

# %% [markdown]
# ## Proportion and admission rate for physics majors of each gender

# %%
# What proportion of female students are majoring in physics?
fem_phys_rate = admits.query("gender == 'female' & major == 'Physics'").count()/ \
    (admits.query("gender == 'female'").count())
print (fem_phys_rate)
# Out:
# student_id    0.120623
# gender        0.120623
# major         0.120623
# admitted      0.120623
# dtype: float64

# %%
admits.query("gender == 'female' & major == 'Physics'").shape[0]/admits.query("gender == 'female'").shape[0]
# Out:
# 0.12062256809338522

# %%
# What proportion of male students are majoring in physics?
fem_phys_rate = admits.query("gender == 'male' & major == 'Physics'").count()/ \
    (admits.query("gender == 'male'").count())
print (fem_phys_rate)
# Out:
# student_id    0.925926
# gender        0.925926
# major         0.925926
# admitted      0.925926
# dtype: float64

# %%
admits.query("gender == 'male' & major == 'Physics'").shape[0]/admits.query("gender == 'male'").shape[0]
# Out:
# 0.9259259259259259

# %%
# Admission rate for female physics majors
len(admits[(admits["gender"]=='female') & (admits["major"] == 'Physics') & admits["admitted"]]) / len(admits[(admits["gender"]=='female') & (admits["major"] == 'Physics')])
# Out:
# 0.7419354838709677

# %%
# Admission rate for male physics majors
len(admits[(admits["gender"]=='male') & (admits["major"] == 'Physics') & admits["admitted"]]) / len(admits[(admits["gender"]=='male') & (admits["major"] == 'Physics')])
# Out:
# 0.5155555555555555

# %% [markdown]
# ## Admission rate for each major

# %%
# Admission rate for physics majors
len(admits[(admits['major'] == 'Physics') & admits['admitted']]) / len(admits[(admits['major'] == 'Physics')])
# Out:
# 0.54296875

# %%
# Admission rate for chemistry majors

len(admits[(admits['major'] == 'Chemistry') & admits['admitted']]) / len(admits[(admits['major'] == 'Chemistry')])
# Out:
# 0.21721311475409835
