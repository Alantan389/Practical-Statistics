# %%
import pandas as pd
import numpy as np
import statistics

# %% [markdown]
# ![Screen%20Shot%202021-12-02%20at%203.39.29%20PM.png](attachment:Screen%20Shot%202021-12-02%20at%203.39.29%20PM.png)
#
#
# ## calculate SUM

# %%
number1=(5,15,3,3,8,10,12)
sum(number1)
# Out:
# 56

# %% [markdown]
# ## calculate MEAN

# %%
number1=(5,15,3,3,8,10,12)
mean=sum(number1)/len(number1)
mean
# Out:
# 8.0

# %% [markdown]
# ![Screen%20Shot%202021-12-02%20at%203.44.53%20PM.png](attachment:Screen%20Shot%202021-12-02%20at%203.44.53%20PM.png)

# %%
number1
# Out:
# (5, 15, 3, 3, 8, 10, 12)

# %%
## select number from number1 range 2-7
number1[1:]
# Out:
# (15, 3, 3, 8, 10, 12)

# %%
sum(number1[1:])+6
# Out:
# 57

# %% [markdown]
# ![Screen%20Shot%202021-12-02%20at%203.45.11%20PM.png](attachment:Screen%20Shot%202021-12-02%20at%203.45.11%20PM.png)

# %%
number1
# Out:
# (5, 15, 3, 3, 8, 10, 12)

# %%
number1[2:6]
# Out:
# (3, 3, 8, 10)

# %%
len(number1)
# Out:
# 7

# %%
sum(number1[2:6])/(len(number1)-1)
# Out:
# 4.0

# %%
number2=(1, 5, 10, 3, 8, 12, 4, 1, 2, 8)

sort1=sorted(number2)

sort1
# Out:
# [1, 1, 2, 3, 4, 5, 8, 8, 10, 12]

# %%
max(sort1)
# Out:
# 12

# %%
min(sort1)
# Out:
# 1

# %%
q3, q1 = np.percentile(sort1, [75 ,25])
iqr = q3 - q1
iqr
# Out:
# 5.75

# %%
q1, q3
# Out:
# (2.25, 8.0)

# %%
first_q=np.quantile(sort1,0.25, interpolation='midpoint')
first_q
# Out:
# 2.5

# %%
np.median(sort1)
# Out:
# 4.5

# %%
number3=(5, 10, 3, 8, 12, 4, 1, 2, 8)

# %%
range2=max(number3)-min(number3)
range2
# Out:
# 11

# %%
first_q1=np.quantile(number3, .25 , interpolation='midpoint')
first_q1
# Out:
# 3.0

# %%
third_q1=np.quantile(number3,0.75, interpolation='midpoint')
third_q1
# Out:
# 8.0

# %%
np.median(number3)
# Out:
# 5.0

# %%
std_dv=(1, 5, 10, 3, 8, 12, 4)

m = statistics.mean(std_dv)

# %%
statistics.stdev(std_dv, xbar=m)
# Out:
# 3.9761191895520196

# %%
statistics.pstdev(std_dv)
# Out:
# 3.6811710647786073

# %% [markdown]
# please click link below to see why use  pvariance and  pstdev
#
# https://stackoverflow.com/questions/54877855/python-statistics-module-returns-different-standard-deviation-than-calculated

# %%
statistics.variance(std_dv, xbar=m)
# Out:
# 15.80952380952381

# %%
statistics.pvariance(std_dv)
# Out:
# 13.551020408163266

# %%
statistics.stdev(std_dv, xbar=m)
# Out:
# 3.9761191895520196

# %%
statistics.pstdev(std_dv)
# Out:
# 3.6811710647786073

# %% [markdown]
# ![Screen%20Shot%202021-12-02%20at%205.09.51%20PM.png](attachment:Screen%20Shot%202021-12-02%20at%205.09.51%20PM.png)

# %%
data= {'year1':['5%','12%'],'year2':['5%','-2%'],'year3':['5%','10%'],'year4':['5%','0%'],'year5':['5%','7%'],'year6':['5%','3%']}

returns=pd.DataFrame(data, index=['Investment1','Investment2'])

returns
# Out:
#             year1 year2 year3 year4 year5 year6
# Investment1    5%    5%    5%    5%    5%    5%
# Investment2   12%   -2%   10%    0%    7%    3%

# %%
returns.describe()
# Out:
#        year1 year2 year3 year4 year5 year6
# count      2     2     2     2     2     2
# unique     2     2     2     2     2     2
# top       5%    5%    5%    5%    5%    5%
# freq       1     1     1     1     1     1

# %% [markdown]
# For the following dataset, match each value to the appropriate label:

# %%
quest1=(15, 4, 3, 8, 15, 22, 7, 9, 2, 3, 3, 12, 6)
quest1
# Out:
# (15, 4, 3, 8, 15, 22, 7, 9, 2, 3, 3, 12, 6)

# %%
range5=max(quest1)-min(quest1)
range5
# Out:
# 20

# %%
n=len(quest1)
n
# Out:
# 13

# %%
median_q1=np.median(quest1)
median_q1
# Out:
# 7.0

# %%
FQ_q1=np.quantile(quest1,0.25, interpolation='midpoint')
FQ_q1
# Out:
# 3.0

# %%
TQ_q1=np.quantile(quest1,0.75, interpolation='midpoint')
TQ_q1
# Out:
# 12.0

# %%
np.percentile(quest1,75,interpolation='midpoint')
# Out:
# 12.0

# %%
mean_q1=statistics.mean(quest1)
mean_q1
# Out:
# 8.384615384615385

# %%
mode_q1=statistics.mode(quest1)
mode_q1
# Out:
# 3

# %%
quest2=(15, 4, 3, 8, 15, 22, 7, 9, 2, 3, 3, 12, 6)

# %%
## INTERQUARTILE RANGE
IQR= np.quantile(quest2,0.75, interpolation='midpoint')-np.quantile(quest2,0.25, interpolation='midpoint')

# %%
IQR
# Out:
# 9.0

# %%
RANGE2=max(quest2)-min(quest2)
RANGE2
# Out:
# 20

# %%
max(quest2), min(quest2)
# Out:
# (22, 2)

# %%
var_q2=statistics.pvariance(quest2)
var_q2
# Out:
# 33.928994082840234

# %%
std_q2=statistics.pstdev(quest2)
std_q2
# Out:
# 5.8248600054284765
